# %% [markdown]
# # Association rules for multiclass prediction

# %% [markdown]
# ## Dataset: CAR Acceptability
#
# Car Evaluation Database was derived from a simple hierarchical decision model originally developed for the demonstration of DEX, M. Bohanec, V. Rajkovic: Expert system for decision making. Sistemica 1(1), pp. 145-157, 1990.). The model evaluates cars according to the following concept structure:
#
# CAR car acceptability
# - PRICE overall price
#   - buying buying price
#   - maint price of the maintenance
# - TECH technical characteristics
#   - COMFORT comfort
#     - doors number of doors
#     - persons capacity in terms of persons to carry
#   - lug_boot the size of luggage boot
#   - safety estimated safety of the car

# %%
# %matplotlib inline

# %%
import pandas as pd
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split

# %%
dataset = pd.read_csv("files/CAR_Acceptability.csv", header=0)

# %%
dataset.head()
# Out:
#   buying  maint doors persons lug_boot safety car_accept
# 0  vhigh  vhigh     2       2    small    low      unacc
# 1  vhigh  vhigh     2       2    small    med      unacc
# 2  vhigh  vhigh     2       2    small   high      unacc
# 3  vhigh  vhigh     2       2      med    low      unacc
# 4  vhigh  vhigh     2       2      med    med      unacc

# %%
dataset.describe()
# Out:
#        buying maint doors persons lug_boot safety car_accept
# count    1728  1728  1728    1728     1728   1728       1728
# unique      4     4     4       3        3      3          4
# top       med   med     3    more      med    med      unacc
# freq      432   432   432     576      576    576       1210

# %% [markdown]
# # Problem: predict car acceptability
#
# ## Multiclass Classification problem
#
# ### One approach: Random forest multiclass prediction

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=10, max_depth=None,
                    min_samples_split=2, random_state=0)

# %%
# It is necessary to encode variables
from sklearn.preprocessing import LabelEncoder

# %%
features = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'car_accept']

# %%
features_enc = [f + '_enc' for f in features]

# %%
dataset_enc = dataset.copy()
le = LabelEncoder()

for f in features:   
    print(f)
    le.fit(dataset[[f]])
    #print(le.classes_)
    dataset_enc[f + '_enc'] = le.transform(dataset[[f]])
# Out:
# buying
# maint
# doors
# persons
# lug_boot
# safety
# car_accept
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:108: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Divide dataset into train and test
train_enc, test_enc = train_test_split(dataset_enc, test_size = 0.3, random_state = 0)

# Save into files
train_enc[features].to_csv("files/CAR_Acceptability_train.csv", header=True, index=False)
test_enc[features].to_csv("files/CAR_Acceptability_test.csv", header=True, index=False)

# %%
# Now we are ready to predict
clf.fit(train_enc[features_enc[0:-1]], train_enc[features_enc[-1]])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
test_enc['pred'] = clf.predict(test_enc[features_enc[0:-1]])
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
test_enc.head()
# Out:
#      buying  maint  doors persons lug_boot safety car_accept  buying_enc  \
# 1318    low  vhigh      2    more      med    med      unacc           1
# 124   vhigh   high      2       4      big    med      unacc           3
# 648    high    med      2       2    small    low      unacc           0
# 249   vhigh    med      3       2      big    low      unacc           3
# 1599    low    med  5more       2      big    low      unacc           1
#
#       maint_enc  doors_enc  persons_enc  lug_boot_enc  safety_enc  \
# 1318          3          0            2             1           2
# 124           0          0            1             0           2
# 648           2          0            0             2           1
# 249           2          1            0             0           1
# 1599          2          3            0             0           1
#
#       car_accept_enc  pred
# 1318               2     2
# 124                2     2
# 648                2     2
# 249                2     2
# 1599               2     2

# %%
### Check accuracy
test_enc['hit'] = 0
test_enc.loc[test_enc['pred'] == test_enc['car_accept_enc'], 'hit'] = 1
test_enc['hit'].mean()
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# 0.9576107899807321

# %% [markdown]
# ## Another approach: Association rules

# %%
dataset.head()
# Out:
#   buying  maint doors persons lug_boot safety car_accept
# 0  vhigh  vhigh     2       2    small    low      unacc
# 1  vhigh  vhigh     2       2    small    med      unacc
# 2  vhigh  vhigh     2       2    small   high      unacc
# 3  vhigh  vhigh     2       2      med    low      unacc
# 4  vhigh  vhigh     2       2      med    med      unacc

# %% [markdown]
# ## Idea
#
# From each observations in the train dataset we can generate multiple rules, all with features in the left hand side and the target variable in the right hand side:
#
# - From first observation
# ```
# ...
# [buy = vhigh]                                                                       => [car_accept = unacc]
# [buy = vhigh] + [mai = vhigh] + [doo = 2]                                           => [car_accept = unacc]
# [buy = vhigh] +               + [doo = 2] + [per = 2]                               => [car_accept = unacc]
# [                                           [per = 2] + [lub = small] + [saf = low] => [car_accept = unacc]
# ...
# ```
#
# - From second observation
# ```
# ...
# [                                                                       [saf = med] => [car_accept = unacc]
# [                                           [per = 2] + [lub = small] + [saf = med] => [car_accept = unacc]
# ...
# ```
#
# ## Pseudocode
#
# ```
# Generate all possible (or selected) rules
#
# Train:
#     For each observation:
#         Update the rules base with values from the observation (features => target)
#
# Predict:
#     For each observation:
#         Apply all rules according with the left hand side of the observation
#         Select the rules with higher support and / or confidence
#         Target(s) are the right hand sides of the selected rules
# ```

# %%
from datetime import timedelta, date, datetime
from heapq import nlargest
from operator import itemgetter
import math
import re

# %%
MIN_SUPPORT = 1
NUM_OPTS = 1
FILE_TRAIN = 'files/CAR_Acceptability_train.csv'
FILE_TEST = 'files/CAR_Acceptability_test.csv'

# %%
antecedents_index = [0,1,2,3,4,5]
target_index = 6

# Generate all possible combinations of attributes
ant_list = []

def list_powerset(lst):
    # the power set of the empty set has one element, the empty set
    result = [[]]
    for x in lst:
        result.extend([subset + [x] for subset in result])
    return result


ant_list = list_powerset(antecedents_index)
ant_collections = {tuple(a): dict() for a in ant_list}
totals = {tuple(a): 0 for a in ant_list}

# %%
def append_rule(antecedents, consequent, weight, rule_collection):
    """
    Antecedents are usually a tuple of matched attributes and consequent
    is the target.
    weight is the weight assigned to the generated rule, instead of just 1.
    rule_collection is the collection to append the generated rule to.
    """
    if antecedents in rule_collection:
        if consequent in rule_collection[antecedents]:
            rule_collection[antecedents][consequent] += weight
        else:
            rule_collection[antecedents][consequent] = weight
        rule_collection[antecedents]['__all__'] += weight
    else:
        rule_collection[antecedents] = {'__all__': weight}
        rule_collection[antecedents][consequent] = weight

# %%
def apply_rules(antecedents, consequents, rule_collection):
    """
    Apply the given rule collection to the antecedents, writing the
    consequents to out.
    Return number of added consequents.
    """
    new_consequents = 0
    if antecedents in rule_collection:
        rule = rule_collection[antecedents]
        support_antecedents = float(rule['__all__']) + 1e-9
        if support_antecedents <= MIN_SUPPORT:
            return 0
        
        # Only one sorting per antecedents for all items
        if 'topitems' in rule:
            topitems = rule['topitems']
        else:
            rule_items = [(target, support / (0.0 + support_antecedents)) 
                for target, support in rule.items() if target != '__all__' 
                    and target != 'topitems' and support >= MIN_SUPPORT]
                    
            topitems = nlargest(NUM_OPTS, rule_items, key=itemgetter(1))
            rule['topitems'] = topitems
            
        # if target already in consequents, add only if higher confidence
        for topitem in topitems:
            target, new_confidence = topitem
            if target in consequents.keys():
                if consequents[target] < new_confidence:
                    consequents[target] = new_confidence
                    new_consequents += 1
            else:  # otherwise just add it to the list
                consequents[target] = new_confidence
                new_consequents += 1

    return new_consequents

# %%
def train():    
    
    myfile = open(FILE_TRAIN, 'r')
    myheader = re.split(',',myfile.readline()[:-1])
    myline = re.split(',',myfile.readline()[:-1])

    while myline is not None and len(myline) > 1:
        # Add rules with current instance
        weight = 1
        conseq = myline[target_index]

        # For each possible antecedent
        for ant in ant_list:
                
            # Get current antecedent
            cur_ant = map(lambda x:myline[x], ant)
            
            # Update complete rule
            append_rule(tuple(cur_ant), conseq, weight, ant_collections[tuple(ant)])
        
        myline = re.split(',',myfile.readline()[:-1])

# %%
def predict():

    num_options = 1
    match, total, sum_apk, sum_match_apk, sum_pos = [0, 0, 0, 0, 0]

    myfile = open(FILE_TEST, 'r')
    myheader = re.split(',',myfile.readline()[:-1])
    myline = re.split(',',myfile.readline()[:-1])
    
    while myline is not None and len(myline) > 1:
        # Add rules with current instance
        weight = 1
        target_real = myline[target_index]
        filled = {}

        # For each possible antecedent
        for ant in ant_list:
            
            # Get current antecedent        
            cur_ant = map(lambda x:myline[x], ant) 
    
            # Apply rule
            totals[tuple(ant)] += apply_rules(tuple(cur_ant), filled, ant_collections[tuple(ant)])
        
        # Select rule(s) with more confidence
        clusters_conf = filled.items()
        clusters_conf = sorted(clusters_conf, key=lambda x: x[1], reverse=True)[:NUM_OPTS]      
        myresult = [c[0] for c in clusters_conf]

        # Evaluate        
        try:
            pos = myresult.index(target_real)
        except:
            pos = -1
            
        current_match = (1 if pos >= 0 and pos < num_options else 0)
        total_res = len(myresult)
        print("{obs} {pred}".format(obs=myline, pred=myresult))    

        # Update metrics
        total += 1        
        match += current_match
        
        myline = re.split(',',myfile.readline()[:-1])
    
    # Final result
    print("\ntotal:\t{}\nmatch:\t{}\nrate:\t{}".format(
            total, 
            match, 
            match / (0.0 + total), 
        ))
    #print(totals)

# %%
train()

# %%
predict()
# Out:
# ['low', 'vhigh', '2', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '2', '4', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', '2', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '5more', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'low', '2', 'more', 'med', 'high', 'good'] ['unacc']
# ['high', 'low', '3', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', '4', 'med', 'high', 'acc'] ['acc']
# ['med', 'low', '3', '4', 'med', 'med', 'acc'] ['unacc']
# ['med', 'high', '2', '4', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '4', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'low', '2', '4', 'med', 'med', 'acc'] ['unacc']
# ['low', 'vhigh', '4', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'med', '3', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '4', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'high', '2', '4', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '4', 'big', 'med', 'acc'] ['acc']
# ['low', 'vhigh', '2', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'low', '2', 'more', 'med', 'high', 'good'] ['vgood']
# ['med', 'vhigh', '5more', 'more', 'big', 'high', 'acc'] ['acc']
# ['low', 'low', '2', 'more', 'med', 'med', 'acc'] ['unacc']
# ['med', 'vhigh', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'high', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', '2', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', 'more', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'low', '3', '4', 'med', 'high', 'good'] ['acc']
# ['high', 'high', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['low', 'low', '2', '4', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'med', '3', '4', 'big', 'high', 'acc'] ['acc']
# ['low', 'low', '4', '4', 'big', 'med', 'good'] ['acc']
# ['high', 'high', '2', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '4', '4', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'low', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '5more', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'med', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', '4', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'med', '4', '2', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'low', '4', 'more', 'big', 'high', 'vgood'] ['vgood']
# ['low', 'vhigh', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '3', '4', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '4', '4', 'big', 'med', 'acc'] ['unacc']
# ['low', 'vhigh', '4', '2', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'low', '5more', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'med', '4', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '4', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '2', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'low', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'med', '4', '2', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', 'more', 'med', 'med', 'acc'] ['good']
# ['med', 'high', '5more', 'more', 'small', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '4', 'more', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'high', '2', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '4', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'high', '2', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['med', 'med', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'low', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'low', '4', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', 'more', 'med', 'high', 'acc'] ['unacc']
# ['high', 'high', '2', 'more', 'med', 'high', 'acc'] ['unacc']
# ['low', 'vhigh', '5more', 'more', 'small', 'high', 'acc'] ['unacc']
# ['low', 'med', '2', 'more', 'med', 'med', 'acc'] ['good']
# ['med', 'med', '3', '4', 'big', 'med', 'acc'] ['acc']
# ['med', 'low', '5more', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'high', '3', 'more', 'small', 'med', 'acc'] ['unacc']
# ['high', 'high', '3', 'more', 'big', 'high', 'acc'] ['acc']
# ['vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', 'more', 'big', 'med', 'acc'] ['acc']
# ['high', 'low', '4', '4', 'big', 'med', 'acc'] ['acc']
# ['low', 'vhigh', '5more', '4', 'med', 'med', 'acc'] ['unacc']
# ['med', 'vhigh', '2', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'low', '4', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'low', '2', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '4', 'med', 'med', 'good'] ['acc']
# ['vhigh', 'vhigh', '2', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'low', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['med', 'high', '3', 'more', 'big', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '5more', 'more', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'low', '3', '2', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'low', '4', '4', 'big', 'high', 'vgood'] ['vgood']
# ['high', 'high', '4', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'high', '2', '4', 'big', 'med', 'acc'] ['unacc']
# ['vhigh', 'med', '2', '4', 'big', 'high', 'acc'] ['acc']
# ['vhigh', 'high', '3', '4', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'med', '4', 'more', 'small', 'high', 'acc'] ['vgood']
# ['high', 'low', '2', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '5more', '4', 'med', 'high', 'vgood'] ['vgood']
# ['high', 'high', '4', 'more', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'high', '3', '4', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'med', '3', '4', 'med', 'high', 'acc'] ['acc']
# ['med', 'vhigh', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'med', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'low', '4', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'med', '2', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'med', '2', '4', 'big', 'med', 'acc'] ['acc']
# ['high', 'high', '3', '4', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'low', '2', '4', 'med', 'high', 'good'] ['unacc']
# ['high', 'high', '2', '4', 'med', 'high', 'acc'] ['acc']
# ['high', 'low', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'low', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'high', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'med', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'high', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'high', '3', 'more', 'med', 'high', 'vgood'] ['acc']
# ['vhigh', 'high', '3', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'low', '2', '2', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '5more', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '2', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'med', '5more', '4', 'med', 'high', 'acc'] ['acc']
# ['low', 'low', '5more', '4', 'big', 'med', 'good'] ['acc']
# ['vhigh', 'vhigh', '3', '4', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'med', '4', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'med', '3', 'more', 'med', 'med', 'acc'] ['acc']
# ['low', 'low', '5more', '4', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '4', 'more', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'low', '2', '2', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'low', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'low', '4', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'low', '4', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '4', 'more', 'small', 'high', 'acc'] ['acc']
# ['med', 'vhigh', '4', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', '4', 'big', 'high', 'acc'] ['acc']
# ['low', 'high', '3', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', '4', 'small', 'high', 'acc'] ['acc']
# ['vhigh', 'med', '5more', '4', 'med', 'med', 'acc'] ['acc']
# ['med', 'med', '3', 'more', 'big', 'med', 'acc'] ['acc']
# ['high', 'high', '2', 'more', 'big', 'med', 'acc'] ['acc']
# ['med', 'low', '5more', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'high', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '5more', '4', 'big', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '5more', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '5more', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'med', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'med', '5more', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'med', '5more', 'more', 'small', 'med', 'acc'] ['good']
# ['vhigh', 'low', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'low', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'high', '2', '4', 'big', 'high', 'acc'] ['acc']
# ['vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'high', '5more', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'med', '3', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '2', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'med', '3', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', '4', 'big', 'med', 'unacc'] ['unacc']
# ['med', 'med', '4', '4', 'med', 'med', 'acc'] ['acc']
# ['vhigh', 'high', '2', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'med', '2', '4', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'high', '2', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'low', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'low', '2', 'more', 'med', 'high', 'acc'] ['acc']
# ['med', 'high', '4', 'more', 'med', 'high', 'acc'] ['acc']
# ['low', 'vhigh', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '5more', '4', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'med', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['vhigh', 'med', '5more', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '4', 'small', 'high', 'good'] ['acc']
# ['vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', '4', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '3', 'more', 'small', 'high', 'acc'] ['unacc']
# ['vhigh', 'low', '4', '2', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '2', '4', 'med', 'high', 'unacc'] ['unacc']
# ['vhigh', 'low', '3', '4', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '5more', 'more', 'small', 'high', 'acc'] ['unacc']
# ['low', 'high', '5more', '2', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'low', '2', 'more', 'big', 'med', 'good'] ['acc']
# ['med', 'low', '4', '2', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '4', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '4', 'big', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '4', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'high', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['vhigh', 'vhigh', '3', 'more', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'med', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '4', '4', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'high', '5more', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'low', '3', '2', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'vhigh', '2', '4', 'big', 'high', 'acc'] ['acc']
# ['vhigh', 'high', '3', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'med', '3', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '3', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'high', '5more', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'high', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'med', '4', '4', 'small', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '4', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'low', '3', '4', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '5more', '4', 'med', 'high', 'acc'] ['acc']
# ['med', 'vhigh', '5more', '4', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'med', '5more', 'more', 'big', 'high', 'vgood'] ['vgood']
# ['low', 'vhigh', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', '2', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'med', '3', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'low', '4', '4', 'med', 'high', 'vgood'] ['acc']
# ['med', 'med', '3', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'high', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'med', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', 'more', 'big', 'med', 'acc'] ['acc']
# ['high', 'vhigh', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'low', '3', '4', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'high', '3', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'high', '4', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', '4', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'high', '2', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '5more', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'low', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'med', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'high', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'med', '5more', '4', 'small', 'high', 'good'] ['acc']
# ['med', 'med', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'med', '4', 'more', 'small', 'high', 'acc'] ['unacc']
# ['med', 'vhigh', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '3', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'med', '5more', '2', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '4', '2', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'low', '4', '4', 'small', 'high', 'good'] ['good']
# ['med', 'high', '5more', '4', 'small', 'high', 'acc'] ['acc']
# ['med', 'med', '3', '4', 'med', 'high', 'acc'] ['acc']
# ['low', 'high', '5more', 'more', 'small', 'high', 'acc'] ['good']
# ['med', 'vhigh', '5more', '4', 'med', 'med', 'acc'] ['acc']
# ['med', 'med', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '5more', '4', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '4', 'more', 'small', 'med', 'acc'] ['acc']
# ['vhigh', 'med', '2', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'high', '2', '4', 'med', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '3', '2', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'high', '4', '4', 'big', 'high', 'vgood'] ['vgood']
# ['vhigh', 'low', '4', '4', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', 'more', 'big', 'med', 'acc'] ['acc']
# ['low', 'high', '2', '4', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'med', '2', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', '4', 'big', 'med', 'acc'] ['acc']
# ['high', 'vhigh', '5more', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '2', '4', 'med', 'high', 'acc'] ['unacc']
# ['low', 'med', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '2', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'high', '3', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '2', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'low', '2', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'low', '4', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '5more', '4', 'big', 'med', 'acc'] ['acc']
# ['med', 'high', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'high', '3', '4', 'med', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '4', '2', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'low', '4', '4', 'med', 'high', 'vgood'] ['acc']
# ['med', 'low', '4', '4', 'big', 'med', 'good'] ['good']
# ['vhigh', 'high', '4', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'high', '4', '2', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'med', '2', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'high', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'low', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'high', '5more', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'low', '3', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'high', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'med', '4', '4', 'big', 'med', 'acc'] ['acc']
# ['high', 'med', '4', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '3', 'more', 'big', 'high', 'acc'] ['acc']
# ['med', 'vhigh', '4', '4', 'big', 'high', 'acc'] ['acc']
# ['low', 'low', '3', '4', 'big', 'med', 'good'] ['acc']
# ['low', 'med', '4', 'more', 'med', 'med', 'good'] ['acc']
# ['vhigh', 'high', '4', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'med', '5more', '4', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'med', '4', '2', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '4', 'small', 'high', 'acc'] ['acc']
# ['low', 'med', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'low', '3', '4', 'small', 'high', 'good'] ['good']
# ['low', 'high', '4', 'more', 'small', 'med', 'acc'] ['unacc']
# ['med', 'low', '5more', '2', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', '4', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'med', '5more', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', '4', 'big', 'med', 'unacc'] ['unacc']
# ['med', 'high', '2', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'high', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '5more', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '3', '4', 'big', 'high', 'acc'] ['acc']
# ['low', 'med', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', '4', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'low', '5more', 'more', 'big', 'med', 'acc'] ['acc']
# ['high', 'med', '5more', '2', 'big', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', '4', 'small', 'high', 'acc'] ['acc']
# ['med', 'high', '3', 'more', 'med', 'med', 'acc'] ['acc']
# ['high', 'low', '5more', '4', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'high', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'high', '4', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'med', '2', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '5more', '4', 'big', 'high', 'acc'] ['acc']
# ['high', 'low', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '3', 'more', 'big', 'med', 'good'] ['good']
# ['vhigh', 'low', '2', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'med', '4', '4', 'big', 'med', 'good'] ['acc']
# ['med', 'vhigh', '3', '2', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'high', '2', 'more', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '5more', '4', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'med', '5more', '4', 'big', 'high', 'vgood'] ['vgood']
# ['vhigh', 'high', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'low', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'high', '4', 'more', 'med', 'high', 'vgood'] ['acc']
# ['low', 'vhigh', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', 'more', 'small', 'high', 'acc'] ['unacc']
# ['vhigh', 'high', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'low', '5more', 'more', 'med', 'med', 'acc'] ['unacc']
# ['low', 'low', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'high', '4', '2', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'low', '3', '4', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', 'more', 'med', 'med', 'acc'] ['acc']
# ['vhigh', 'high', '4', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'low', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'low', '5more', 'more', 'small', 'med', 'acc'] ['acc']
# ['high', 'low', '4', '4', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'high', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'low', '4', '2', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'low', '5more', 'more', 'big', 'high', 'acc'] ['acc']
# ['vhigh', 'vhigh', '2', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'high', '5more', '4', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'vhigh', '3', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'high', '5more', '4', 'small', 'high', 'acc'] ['acc']
# ['high', 'med', '2', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'] ['unacc']
# ['med', 'low', '4', 'more', 'small', 'high', 'good'] ['acc']
# ['low', 'high', '4', 'more', 'big', 'high', 'vgood'] ['vgood']
# ['vhigh', 'med', '5more', 'more', 'med', 'med', 'acc'] ['unacc']
# ['high', 'low', '5more', '4', 'big', 'med', 'acc'] ['acc']
# ['med', 'high', '3', '2', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'high', '5more', 'more', 'med', 'high', 'vgood'] ['acc']
# ['high', 'vhigh', '3', '2', 'small', 'high', 'unacc'] ['unacc']
# ['med', 'high', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '3', '2', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '4', 'small', 'med', 'acc'] ['acc']
# ['low', 'high', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'med', '5more', '2', 'big', 'high', 'unacc'] ['unacc']
# ['med', 'low', '2', 'more', 'med', 'med', 'acc'] ['good']
# ['vhigh', 'med', '4', 'more', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', 'more', 'small', 'high', 'acc'] ['acc']
# ['low', 'low', '5more', 'more', 'med', 'med', 'good'] ['good']
# ['med', 'high', '4', '2', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'med', '3', '4', 'big', 'med', 'good'] ['acc']
# ['vhigh', 'high', '5more', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'high', '2', '4', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'med', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'low', '2', 'more', 'big', 'med', 'acc'] ['acc']
# ['med', 'med', '3', '2', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'high', '4', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'low', '2', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['low', 'med', '5more', 'more', 'med', 'high', 'vgood'] ['unacc']
# ['low', 'low', '3', '4', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '4', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '2', 'more', 'med', 'high', 'acc'] ['unacc']
# ['vhigh', 'low', '5more', '2', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'vhigh', '3', '2', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'med', '3', 'more', 'small', 'med', 'acc'] ['acc']
# ['vhigh', 'high', '5more', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '5more', 'more', 'big', 'med', 'acc'] ['acc']
# ['high', 'vhigh', '2', '2', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'high', '5more', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '4', 'big', 'high', 'vgood'] ['vgood']
# ['high', 'high', '3', '2', 'med', 'high', 'unacc'] ['unacc']
# ['med', 'med', '5more', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '4', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '5more', 'more', 'med', 'high', 'unacc'] ['unacc']
# ['med', 'vhigh', '4', 'more', 'big', 'med', 'acc'] ['acc']
# ['med', 'vhigh', '4', '4', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '5more', '4', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '4', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'high', '4', '4', 'big', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '2', '2', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '4', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'low', '3', '4', 'small', 'med', 'acc'] ['acc']
# ['low', 'vhigh', '2', '4', 'med', 'high', 'acc'] ['unacc']
# ['high', 'vhigh', '5more', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'low', '3', '4', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'] ['unacc']
# ['low', 'med', '2', 'more', 'big', 'med', 'good'] ['acc']
# ['med', 'med', '3', '4', 'big', 'high', 'vgood'] ['vgood']
# ['low', 'high', '2', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '4', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '4', '4', 'big', 'high', 'vgood'] ['vgood']
# ['med', 'vhigh', '5more', '4', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'low', '4', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'med', '5more', 'more', 'med', 'high', 'acc'] ['acc']
# ['high', 'med', '5more', '4', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'high', '5more', '4', 'big', 'high', 'acc'] ['acc']
# ['high', 'vhigh', '5more', '2', 'big', 'med', 'unacc'] ['unacc']
# ['high', 'high', '5more', '2', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'high', '3', 'more', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'vhigh', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '4', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'high', '4', 'more', 'small', 'high', 'acc'] ['acc']
# ['med', 'high', '2', 'more', 'big', 'med', 'acc'] ['unacc']
# ['med', 'med', '3', 'more', 'small', 'high', 'acc'] ['vgood']
# ['high', 'vhigh', '2', '2', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', 'more', 'med', 'high', 'unacc'] ['unacc']
# ['med', 'vhigh', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['vhigh', 'high', '5more', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['high', 'high', '2', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'med', '5more', 'more', 'small', 'med', 'acc'] ['acc']
# ['low', 'low', '4', '2', 'big', 'high', 'unacc'] ['unacc']
# ['vhigh', 'low', '3', '2', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'low', '5more', '2', 'med', 'med', 'unacc'] ['unacc']
# ['med', 'high', '2', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'med', '4', '2', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '3', '4', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '4', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'low', '2', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '3', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '2', 'big', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', '2', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['vhigh', 'med', '2', '2', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'vhigh', '2', '2', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'low', '3', '2', 'med', 'high', 'unacc'] ['unacc']
# ['med', 'vhigh', '5more', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'vhigh', '4', '2', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'vhigh', '4', 'more', 'small', 'high', 'acc'] ['unacc']
# ['med', 'low', '2', '4', 'small', 'high', 'good'] ['acc']
# ['vhigh', 'low', '3', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '4', 'more', 'big', 'med', 'acc'] ['acc']
# ['vhigh', 'low', '3', '4', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'high', '2', '2', 'med', 'high', 'unacc'] ['unacc']
# ['high', 'low', '4', '2', 'small', 'med', 'unacc'] ['unacc']
# ['high', 'low', '2', 'more', 'small', 'high', 'unacc'] ['unacc']
# ['high', 'high', '4', '4', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'high', '5more', '4', 'med', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '2', '4', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'high', '4', 'more', 'med', 'med', 'acc'] ['acc']
# ['med', 'med', '4', '4', 'small', 'high', 'acc'] ['acc']
# ['vhigh', 'low', '4', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'low', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'low', '4', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '5more', '2', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'med', '2', '4', 'med', 'med', 'acc'] ['acc']
# ['med', 'vhigh', '3', '4', 'med', 'high', 'acc'] ['acc']
# ['high', 'high', '3', '2', 'small', 'low', 'unacc'] ['unacc']
# ['high', 'high', '3', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '3', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'med', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'high', '3', '2', 'big', 'med', 'unacc'] ['unacc']
# ['low', 'vhigh', '2', 'more', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'low', '2', '2', 'small', 'low', 'unacc'] ['unacc']
# ['low', 'vhigh', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['vhigh', 'low', '3', '4', 'small', 'high', 'acc'] ['acc']
# ['med', 'high', '3', '4', 'big', 'med', 'acc'] ['acc']
# ['high', 'vhigh', '2', 'more', 'big', 'high', 'unacc'] ['unacc']
# ['vhigh', 'vhigh', '3', '4', 'big', 'low', 'unacc'] ['unacc']
# ['low', 'med', '2', '4', 'small', 'high', 'good'] ['acc']
# ['high', 'high', '2', '4', 'med', 'med', 'unacc'] ['unacc']
# ['high', 'high', '4', '2', 'big', 'high', 'unacc'] ['unacc']
# ['low', 'high', '4', 'more', 'med', 'med', 'acc'] ['acc']
# ['vhigh', 'med', '4', '2', 'big', 'low', 'unacc'] ['unacc']
# ['med', 'low', '5more', '4', 'big', 'med', 'good'] ['good']
# ['vhigh', 'high', '4', 'more', 'med', 'med', 'unacc'] ['unacc']
# ['low', 'med', '3', '2', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'low', '4', 'more', 'big', 'med', 'good'] ['acc']
# ['high', 'vhigh', '5more', '4', 'med', 'high', 'unacc'] ['unacc']
# ['low', 'med', '5more', '4', 'small', 'low', 'unacc'] ['unacc']
# ['med', 'med', '4', '4', 'med', 'low', 'unacc'] ['unacc']
# ['low', 'med', '4', '2', 'med', 'high', 'unacc'] ['unacc']
# ['vhigh', 'low', '3', 'more', 'big', 'med', 'acc'] ['acc']
# ['low', 'med', '2', '2', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'high', '4', 'more', 'big', 'low', 'unacc'] ['unacc']
# ['high', 'high', '4', '2', 'med', 'low', 'unacc'] ['unacc']
# ['med', 'vhigh', '3', '4', 'big', 'low', 'unacc'] ['unacc']
# ['vhigh', 'med', '5more', '4', 'med', 'low', 'unacc'] ['unacc']
# ['high', 'low', '5more', '2', 'small', 'med', 'unacc'] ['unacc']
# ['med', 'high', '5more', 'more', 'med', 'high', 'acc'] ['acc']
# ['low', 'high', '3', 'more', 'med', 'med', 'acc'] ['acc']
#
# total:	519
# match:	465
# rate:	0.895953757225
